# %% [markdown]
# # Bibliotecas

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pylab as plt
import matplotlib.ticker as ticker

# %% [markdown]
# # Leitura dos arquivos

# %%
t_path = os.getcwd()

# %%
arquivo = "\\chuvas_2014_a_2021\\chuvas_2021.csv"

# %%
df = pd.read_csv(t_path+arquivo
                     ,sep = ','
                     ,decimal='.'
                      )

# %%
df
# Out:
#                       tempo  id_estacao nome_estacao_original  indice_pluv  \
# 0       2021-01-01 00:00:00         500      BAIRRO DE FÁTIMA          0.0
# 1       2021-01-01 00:00:00         501             BARRETO 1          0.0
# 2       2021-01-01 00:00:00         502             BOA VISTA          0.0
# 3       2021-01-01 00:00:00         503              BONFIM 2          0.0
# 4       2021-01-01 00:00:00         504              CARAMUJO          0.0
# ...                     ...         ...                   ...          ...
# 265657  2021-12-30 20:15:00         528      TRAVESSA BELTRÃO          5.0
# 265658  2021-12-30 20:15:00         529      VÁRZEA DAS MOÇAS          0.0
# 265659  2021-12-30 20:30:00         501             BARRETO 1          0.4
# 265660  2021-12-30 20:30:00         506       CORONEL LEÔNCIO          0.2
# 265661  2021-12-30 20:30:00         517       MORRO DO ESTADO          1.0
#
# ...
