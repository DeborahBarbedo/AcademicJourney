# %% [markdown]
# # Pacotes

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Importacao dos dados

# %%
df = pd.read_csv('df_norm.csv',index_col="tempo_x", parse_dates=True).iloc[:7000]

# %%
df = df.rename_axis('tempo')

# %%
df
# Out:
#                      Unnamed: 0.1  Unnamed: 0  n_coord  id_estacao  \
# tempo
# 2023-02-27 09:00:00             0           0     1773         500
# 2023-02-27 09:00:00             1           1     1805         500
# 2023-02-27 09:00:00             2           2     1843         500
# 2023-02-27 09:00:00             3           3     1844         500
# 2023-02-27 09:00:00             4           4     1909         500
# ...                           ...         ...      ...         ...
# 2022-04-28 09:00:00          6995        6995     1844         500
# 2022-04-28 09:00:00          6996        6996     1909         500
# 2022-04-28 09:00:00          6997        6997     1910         500
# 2022-04-28 09:00:00          6998        6998     1911         500
# 2022-04-28 09:00:00          6999        6999     1945         500
#
#                      ocorrencia   lon_ocr   lat_ocr  id_tempo_x  \
# tempo
# 2023-02-27 09:00:00         0.0  0.129189  0.717247    13756861
# 2023-02-27 09:00:00         0.0  0.135995  0.722231    13756861
# 2023-02-27 09:00:00         0.0  0.125518  0.731957    13756861
# 2023-02-27 09:00:00         0.0  0.142800  0.730863    13756861
# 2023-02-27 09:00:00         0.0  0.132861  0.749553    13756861
# ...                         ...       ...       ...         ...
# 2022-04-28 09:00:00         0.0  0.142800  0.730863    13317661
# 2022-04-28 09:00:00         0.0  0.132861  0.749553    13317661
# 2022-04-28 09:00:00         0.0  0.139493  0.746269    13317661
# 2022-04-28 09:00:00         0.0  0.148661  0.744051    13317661
# 2022-04-28 09:00:00         0.0  0.139260  0.756666    13317661
#
#                      vintequatrohoras  Altitude_numerica  ...  \
# tempo                                                     ...
# 2023-02-27 09:00:00        -11.512925           3.572899  ...
# 2023-02-27 09:00:00        -11.512925           3.834609  ...
# 2023-02-27 09:00:00        -11.512925           3.708829  ...
# 2023-02-27 09:00:00        -11.512925           3.554743  ...
# 2023-02-27 09:00:00        -11.512925           3.423326  ...
# ...                               ...                ...  ...
# 2022-04-28 09:00:00        -11.512925           3.554743  ...
# 2022-04-28 09:00:00        -11.512925           3.423326  ...
# 2022-04-28 09:00:00        -11.512925           4.318494  ...
# 2022-04-28 09:00:00        -11.512925           3.983693  ...
# 2022-04-28 09:00:00        -11.512925           4.399273  ...
#
#                      flg_comunidades  flg_agricola  flg_exploracao_mineral  \
# tempo
# 2023-02-27 09:00:00                0             0                       0
# 2023-02-27 09:00:00                0             0                       0
# 2023-02-27 09:00:00                0             0                       0
# 2023-02-27 09:00:00                0             0                       0
# 2023-02-27 09:00:00                0             0                       0
# ...                              ...           ...                     ...
# 2022-04-28 09:00:00                0             0                       0
# 2022-04-28 09:00:00                0             0                       0
# 2022-04-28 09:00:00                0             0                       0
# 2022-04-28 09:00:00                1             0                       0
# 2022-04-28 09:00:00                0             0                       0
#
#                      flg_rocha  flg_cobertura_vegetal  \
# tempo
# 2023-02-27 09:00:00          0                      0
# 2023-02-27 09:00:00          0                      0
# 2023-02-27 09:00:00          0                      0
# 2023-02-27 09:00:00          0                      0
# 2023-02-27 09:00:00          0                      0
# ...                        ...                    ...
# 2022-04-28 09:00:00          0                      0
# 2022-04-28 09:00:00          0                      0
# 2022-04-28 09:00:00          0                      0
# 2022-04-28 09:00:00          0                      0
# 2022-04-28 09:00:00          0                      0
#
#                      flg_afloramento_rochoso  flg_favela  \
# tempo
# 2023-02-27 09:00:00                        0           0
# 2023-02-27 09:00:00                        0           0
# 2023-02-27 09:00:00                        0           0
# 2023-02-27 09:00:00                        0           0
# 2023-02-27 09:00:00                        0           0
# ...                                      ...         ...
# 2022-04-28 09:00:00                        0           0
# 2022-04-28 09:00:00                        0           0
# 2022-04-28 09:00:00                        0           1
# 2022-04-28 09:00:00                        0           0
# 2022-04-28 09:00:00                        0           1
#
#                      flg_ocupacao_desordenada  flg_areas_de_risco   graurisc
# tempo
# 2023-02-27 09:00:00                         0                   0 -11.512925
# 2023-02-27 09:00:00                         0                   0 -11.512925
# 2023-02-27 09:00:00                         0                   0 -11.512925
# 2023-02-27 09:00:00                         0                   0 -11.512925
# 2023-02-27 09:00:00                         0                   0 -11.512925
# ...                                       ...                 ...        ...
# 2022-04-28 09:00:00                         0                   0 -11.512925
# 2022-04-28 09:00:00                         0                   0 -11.512925
# 2022-04-28 09:00:00                         0                   0 -11.512925
# 2022-04-28 09:00:00                         1                   0 -11.512925
# 2022-04-28 09:00:00                         0                   0 -11.512925
#
# [7000 rows x 51 columns]

# %%
df = df[['n_coord'
         ,'ocorrencia'
         , "vintequatrohoras"
         , "Altitude_numerica"
         , "Declividade_numerica"
         , "graurisc"
         , 'lon_ocr'
         , 'lat_ocr'
         , 'Orientacao_numerica'
         , 'Curv_Vertical_numerica'
         , 'Curv_Horizontal_numerica'
         , 'Relevo_sombreado_numerico'
         ,'Vegetacao_Natural_Dominante'                
,'Area_Antropica_Dominante'                   
,'legenda_2_Pecuária (pastagens)'             
,'Floresta_Ombrofila_Densa'                   
,'Formacao_Pioneira'                          
,'Floresta_Ombrofila_Densa_Submontana'        
,'Influencia_urbana'                          
,'Vegetacao_Secundaria'                       
,'Argilossolo'                                
,'Gleissolo'                                  
,'Argilossolo_Vermelho_Amarelo'               
,'Gleissolo_Melanico'                         
,'Area_Urbana'                                
,'Unidades_de_Conservacao_Protecao_Integral'  
,'Plano_de_Manejo'                            
,'flg_comunidades'                          
,'flg_agricola'                               
,'flg_exploracao_mineral'                     
,'flg_rocha'                                  
,'flg_cobertura_vegetal'                      
,'flg_afloramento_rochoso'                                                    
,'flg_ocupacao_desordenada' ]].sort_index()

# %%
print(df.index.min())
print(df.index.max())
# Out:
# 2019-02-01 09:00:00
# 2019-02-03 09:00:00

# %%
df_coords = df[['n_coord'
         , "Altitude_numerica"
         , "Declividade_numerica"
         , "graurisc"
         , 'lon_ocr'
         , 'lat_ocr'
         , 'Orientacao_numerica'
         , 'Curv_Vertical_numerica'
         , 'Curv_Horizontal_numerica'
         , 'Relevo_sombreado_numerico'
         ,'Vegetacao_Natural_Dominante'                
,'Area_Antropica_Dominante'                   
,'legenda_2_Pecuária (pastagens)'             
,'Floresta_Ombrofila_Densa'                   
,'Formacao_Pioneira'                          
,'Floresta_Ombrofila_Densa_Submontana'        
,'Influencia_urbana'                          
,'Vegetacao_Secundaria'                       
,'Argilossolo'                                
,'Gleissolo'                                  
,'Argilossolo_Vermelho_Amarelo'               
,'Gleissolo_Melanico'                         
,'Area_Urbana'                                
,'Unidades_de_Conservacao_Protecao_Integral'  
,'Plano_de_Manejo'                            
,'flg_comunidades'                          
,'flg_agricola'                               
,'flg_exploracao_mineral'                     
,'flg_rocha'                                  
,'flg_cobertura_vegetal'                      
,'flg_afloramento_rochoso'                                                    
,'flg_ocupacao_desordenada' ]].drop_duplicates().reset_index(drop=True)

# %%
# Coordenadas
c = sorted(df_coords['n_coord'].unique())

# %%
coluna1 = [0]* len(df_coords['n_coord'].unique())
coluna2 = [np.nan]* len(df_coords['n_coord'].unique())

df_coords.insert(1, "ocorrencia", coluna1)
df_coords.insert(2, "vintequatrohoras", coluna2)

# %%
 # Data 1 dia
df['tempo'] = df.index
d = sorted(df['tempo'].unique())

# %%
for i in d:
    
    sub_d = df[df.loc[:,'tempo'] == i]
    
    for j in c:
        
        if j not in sub_d[['n_coord']].values:
            
            aux = df_coords[df_coords.loc[:,'n_coord'] == j]
            aux = aux.assign(tempo=i)
            
            
            
            df = pd.concat([df, aux], ignore_index=True)

# %%
df['vintequatrohoras'] = df.groupby(['lat_ocr', 'lon_ocr']).apply(lambda x: x[['vintequatrohoras']].interpolate())
# Out:
# /tmp/ipykernel_3844124/129839244.py:1: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   df['vintequatrohoras'] = df.groupby(['lat_ocr', 'lon_ocr']).apply(lambda x: x[['vintequatrohoras']].interpolate())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9405 entries, 0 to 9404
# Data columns (total 35 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   n_coord                                    9405 non-null   int64
#  1   ocorrencia                                 9405 non-null   int64
#  2   vintequatrohoras                           9405 non-null   float64
#  3   Altitude_numerica                          9405 non-null   float64
#  4   Declividade_numerica                       9405 non-null   float64
#  5   graurisc                                   9405 non-null   float64
#  6   lon_ocr                                    9405 non-null   float64
#  7   lat_ocr                                    9405 non-null   float64
#  8   Orientacao_numerica                        9405 non-null   float64
#  9   Curv_Vertical_numerica                     9405 non-null   float64
#  10  Curv_Horizontal_numerica                   9405 non-null   float64
#  11  Relevo_sombreado_numerico                  9405 non-null   float64
#  12  Vegetacao_Natural_Dominante                9405 non-null   int64
#  13  Area_Antropica_Dominante                   9405 non-null   int64
#  14  legenda_2_Pecuária (pastagens)             9405 non-null   int64
#  15  Floresta_Ombrofila_Densa                   9405 non-null   int64
#  16  Formacao_Pioneira                          9405 non-null   int64
#  17  Floresta_Ombrofila_Densa_Submontana        9405 non-null   int64
#  18  Influencia_urbana                          9405 non-null   int64
#  19  Vegetacao_Secundaria                       9405 non-null   int64
#  20  Argilossolo                                9405 non-null   int64
#  21  Gleissolo                                  9405 non-null   int64
#  22  Argilossolo_Vermelho_Amarelo               9405 non-null   int64
#  23  Gleissolo_Melanico                         9405 non-null   int64
#  24  Area_Urbana                                9405 non-null   int64
#  25  Unidades_de_Conservacao_Protecao_Integral  9405 non-null   int64
#  26  Plano_de_Manejo                            9405 non-null   int64
#  27  flg_comunidades                            9405 non-null   int64
#  28  flg_agricola                               9405 non-null   int64
#  29  flg_exploracao_mineral                     9405 non-null   int64
#  30  flg_rocha                                  9405 non-null   int64
#  31  flg_cobertura_vegetal                      9405 non-null   int64
#  32  flg_afloramento_rochoso                    9405 non-null   int64
#  33  flg_ocupacao_desordenada                   9405 non-null   int64
#  34  tempo                                      9405 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(10), int64(24)
# memory usage: 2.5 MB

# %%
df.replace(np.nan,-1, inplace=True)

# %%
df.to_csv('df_comp2.csv')
