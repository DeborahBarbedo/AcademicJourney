# %% [markdown]
# # Pacotes

# %%
import pandas as pd
import numpy as np

from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from prettytable import PrettyTable
import sklearn
from sklearn.metrics import confusion_matrix

import time
from tensorflow import keras
import tensorflow as tf
from keras.models import Sequential
from keras.models import Sequential
from keras.layers import Dense, LSTM, Bidirectional, Flatten #Global max pullin avg max pulling
from keras.layers import  Masking
from keras.regularizers import l2

from keras.callbacks import EarlyStopping, ModelCheckpoint

tf.config.list_physical_devices('GPU')

# fix random seed for reproducibility
seed = 42
tf.random.set_seed(seed)
# Out:
# 2023-04-27 09:01:10.502582: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-27 09:01:10.559272: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-04-27 09:01:10.561207: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-04-27 09:01:10.561216: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-04-27 09:01:10.869993: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-04-27 09:01:10.870022: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-04-27 09:01:10.870024: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-04-27 09:01:11.163927: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:267] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2023-04-27 09:01:11.163966: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: pdpachuvas
# 2023-04-27 09:01:11.163973: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: pdpachuvas
# 2023-04-27 09:01:11.164069: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 525.105.17
# 2023-04-27 09:01:11.164096: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 525.89.2
# 2023-04-27 09:01:11.164101: E tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 525.89.2 does not match DSO version 525.105.17 -- cannot find working devices in this configuration

# %% [markdown]
# # Funcoes

# %%
##############################
###### Matriz de confusão ####
##############################

def matriz_confusao(y_real,y_predito,modelo):

### Grafico ###

  tabela=confusion_matrix(y_real,y_predito)

  group_names = ["True Neg","False Pos","False Neg","True Pos"]
  group_counts = ["{0:0.0f}".format(value) for value in
                tabela.flatten()]
  group_percentages = ["{0:.5%}".format(value) for value in
                     tabela.flatten()/np.sum(tabela)]
  labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
  labels = np.asarray(labels).reshape(2,2)
  f = plt.figure()
  f.set_figwidth(8)
  f.set_figheight(8)

  sns.heatmap(tabela, annot=labels, fmt="", cmap='Blues')

### Tabela ###
  Resultados=PrettyTable()
  Resultados.field_names=["Métrica","Resultado"]
  Resultados.title= modelo
  Resultados.align["Métrica"]="l"
  Resultados.align["Resultado"]="r"

  Resultados.add_row(["Acurácia:",round(sklearn.metrics.accuracy_score(y_real,y_predito),2)])
  Resultados.add_row(["Precisão:",round(sklearn.metrics.precision_score(y_real,y_predito),2)])
  Resultados.add_row(["Recall:",round(sklearn.metrics.recall_score(y_real,y_predito),2)])
  Resultados.add_row(["F1-Score:",round(sklearn.metrics.f1_score(y_real,y_predito),2)])

  print(Resultados)
  
  return



    
def transformacao_estrutura(df):
    '''
    Extrai os atributos do dataframe pandas

    Params:
    -------
    df: dataframe de entrada

    Returns:
    par X, Y
    '''

    X = df[[
       'vintequatrohoras'
     ,'Altitude_numerica'
     ,'Declividade_numerica'
     ,'graurisc'
#     ,'lon_ocr'
#     ,'lat_ocr'
     ,'Orientacao_numerica'
     ,'Curv_Vertical_numerica'
#     ,'Curv_Horizontal_numerica'
     ,'Relevo_sombreado_numerico'
#     ,'Vegetacao_Natural_Dominante'                
     ,'Area_Antropica_Dominante'                   
#     ,'legenda_2_Pecuária (pastagens)'             
     ,'Floresta_Ombrofila_Densa'                   
#     ,'Formacao_Pioneira'                          
#     ,'Floresta_Ombrofila_Densa_Submontana'        
     ,'Influencia_urbana'                          
#     ,'Vegetacao_Secundaria'                       
#     ,'Argilossolo'                                
     ,'Gleissolo'                                  
#     ,'Argilossolo_Vermelho_Amarelo'               
#     ,'Gleissolo_Melanico'                         
     ,'Area_Urbana'                                
     ,'Unidades_de_Conservacao_Protecao_Integral'  
#     ,'Plano_de_Manejo'                            
     ,'flg_comunidades'                          
#     ,'flg_agricola'                               
#     ,'flg_exploracao_mineral'                     
#     ,'flg_rocha'                                  
     ,'flg_cobertura_vegetal'                      
#     ,'flg_afloramento_rochoso'                    
#     ,'flg_favela'                                 
#     ,'flg_ocupacao_desordenada'
           ]]
    


    
    Y = df[['ocorrencia']]
    
    n_tempo, n_coord = conta_tempos_e_coordenadas(df)
    
    X_transformado = X.to_numpy().astype(np.float32).reshape(n_tempo , n_coord, -1)
    Y_transformado = Y.to_numpy().astype(np.float32).reshape(n_tempo , n_coord, -1)
    
    return X_transformado, Y_transformado

    
def conta_tempos_e_coordenadas(df):
    '''
    Conta o número de tempos e coordenadas de um dataframe

    Params:
    -------
    df: dataframe com os atributos 'tempo', e 'n_coord'

    Returns:
    --------
    tupla número de tempos, número de coordenadas
    '''
    tempo = len(df['tempo'].unique())
    n_coord = len(df['n_coord'].unique())

    return tempo, n_coord


def calcula_sample_weight(df,peso):
    '''
    Calcula os pesos para as amostras de treinamento
    '''
    
    Y = df[['ocorrencia']]
    sample_weight_ = list(Y['ocorrencia'])
    
    series = pd.Series(sample_weight_)
    series = series*peso #3191848/613
    series = series+1
    series = series/(peso+1)
    
    sample_weight_ = np.array(list(series)).astype(np.float32)
    
    return sample_weight_

# %% [markdown]
# # Importacao dos dados

# %%
df = pd.read_csv('df_comp.csv')

# %%
df.replace(np.nan,-1, inplace=True)

# %%
df['tempo'] =  pd.to_datetime(df['tempo'])

# %%
df = df.sort_values(['tempo','n_coord'])

# %% [markdown]
# Manter fixo:
#
# * Teste  - 3 meses
#
# Deslizar:
#
# * Treinamento - 2 anos
#
# * Validação - 6 meses

# %%
treino = df[df.loc[:,'tempo'] <= pd.to_datetime('2021-02-24 09:00:00')]

# %%
filtro_inferior = pd.to_datetime('2021-02-24 09:00:00') < df.loc[:, 'tempo']
filtro_superior = df.loc[:, 'tempo'] <= pd.to_datetime('2021-08-24 09:00:00')
validacao = df[filtro_inferior & filtro_superior]

# %%
teste = df[df.loc[:,'tempo'] > pd.to_datetime('2021-08-24 09:00:00')]

# %%
### Treino

X_train, Y_train = transformacao_estrutura(treino)

### Validação

X_val, Y_val = transformacao_estrutura(validacao)

### Teste

X_teste, Y_teste = transformacao_estrutura(teste)

# %% [markdown]
# class_weight_ = {0: (1/3191848),
#                 1: (1/613)}

# %%
print('Treino')
qtd_o = sum(treino['ocorrencia'])
tam_o = len(treino['ocorrencia'])
print(qtd_o)
print(tam_o)
print(tam_o/qtd_o) #peso

print('Validação')
qtd_o = sum(validacao['ocorrencia'])
tam_o = len(validacao['ocorrencia'])
print(qtd_o)
print(tam_o)

print('Teste')
qtd_o = sum(teste['ocorrencia'])
tam_o = len(teste['ocorrencia'])
print(qtd_o)
print(tam_o)
# Out:
# Treino
# 284
# 1555500
# 5477.112676056338
# Validação
# 3
# 384625
# Teste
# 33
# 306000

# %%
sample_weight_ = np.asarray(calcula_sample_weight(treino,5600)).astype(np.float32)

# %%
print(sample_weight_.max())
print(sample_weight_.min())
# Out:
# 1.0
# 0.00017853954

# %%
sample_weight_transformado = sample_weight_.reshape(len(treino['tempo'].unique()), len(treino['n_coord'].unique()), -1)

# %%
sample_weight_transformado.shape
# Out:
# (732, 2125, 1)

# %%
X_val.shape
# Out:
# (181, 2125, 15)

# %%
print(Y_train.shape)
print(X_train.shape)
# Out:
# (732, 2125, 1)
# (732, 2125, 15)

# %%
X_train
# Out:
# array([[[-1.6094379e+00,  3.5240257e+00,  3.8144834e+00, ...,
#           1.0000000e+00,  0.0000000e+00,  1.0000000e+00],
#         [ 9.9999997e-06,  3.9632485e+00,  3.7411430e+00, ...,
#           1.0000000e+00,  0.0000000e+00,  1.0000000e+00],
#         [ 9.9999997e-06,  4.0188570e+00,  3.9687700e+00, ...,
#           1.0000000e+00,  0.0000000e+00,  1.0000000e+00],
#         ...,
#         [ 9.9999997e-06,  4.6761074e+00,  2.9087219e+00, ...,
#           0.0000000e+00,  1.0000000e+00,  0.0000000e+00],
#         [ 9.9999997e-06,  3.2434185e+00,  7.7471977e-01, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 9.9999997e-06,  4.1019115e+00,  3.2507536e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00]],
#
#        [[ 9.9999997e-06,  3.5240257e+00,  3.8144834e+00, ...,
#           1.0000000e+00,  0.0000000e+00,  1.0000000e+00],
#         [ 9.9999997e-06,  3.9632485e+00,  3.7411430e+00, ...,
#           1.0000000e+00,  0.0000000e+00,  1.0000000e+00],
#         [ 9.9999997e-06,  4.0188570e+00,  3.9687700e+00, ...,
#           1.0000000e+00,  0.0000000e+00,  1.0000000e+00],
#         ...,
#         [ 9.9999997e-06,  4.6761074e+00,  2.9087219e+00, ...,
#           0.0000000e+00,  1.0000000e+00,  0.0000000e+00],
#         [ 9.9999997e-06,  3.2434185e+00,  7.7471977e-01, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 9.9999997e-06,  4.1019115e+00,  3.2507536e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00]],
#
#        [[ 1.4350846e+00,  3.5240257e+00,  3.8144834e+00, ...,
#           1.0000000e+00,  0.0000000e+00,  1.0000000e+00],
#         [ 1.1631508e+00,  3.9632485e+00,  3.7411430e+00, ...,
#           1.0000000e+00,  0.0000000e+00,  1.0000000e+00],
#         [ 1.1631508e+00,  4.0188570e+00,  3.9687700e+00, ...,
#           1.0000000e+00,  0.0000000e+00,  1.0000000e+00],
#         ...,
#         [ 2.2192035e+00,  4.6761074e+00,  2.9087219e+00, ...,
#           0.0000000e+00,  1.0000000e+00,  0.0000000e+00],
#         [ 1.0986123e+00,  3.2434185e+00,  7.7471977e-01, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 1.0986123e+00,  4.1019115e+00,  3.2507536e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00]],
#
#        ...,
#
#        [[ 1.6486586e+00,  3.5240257e+00,  3.8144834e+00, ...,
#           1.0000000e+00,  0.0000000e+00,  1.0000000e+00],
#         [ 9.9999997e-06,  3.9632485e+00,  3.7411430e+00, ...,
#           1.0000000e+00,  0.0000000e+00,  1.0000000e+00],
#         [ 9.9999997e-06,  4.0188570e+00,  3.9687700e+00, ...,
#           1.0000000e+00,  0.0000000e+00,  1.0000000e+00],
#         ...,
#         [ 2.3418057e+00,  4.6761074e+00,  2.9087219e+00, ...,
#           0.0000000e+00,  1.0000000e+00,  0.0000000e+00],
#         [ 9.9999997e-06,  3.2434185e+00,  7.7471977e-01, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 9.9999997e-06,  4.1019115e+00,  3.2507536e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00]],
#
#        [[-2.2314355e-01,  3.5240257e+00,  3.8144834e+00, ...,
#           1.0000000e+00,  0.0000000e+00,  1.0000000e+00],
#         [-9.1629076e-01,  3.9632485e+00,  3.7411430e+00, ...,
#           1.0000000e+00,  0.0000000e+00,  1.0000000e+00],
#         [-9.1629076e-01,  4.0188570e+00,  3.9687700e+00, ...,
#           1.0000000e+00,  0.0000000e+00,  1.0000000e+00],
#         ...,
#         [ 2.0014801e+00,  4.6761074e+00,  2.9087219e+00, ...,
#           0.0000000e+00,  1.0000000e+00,  0.0000000e+00],
#         [ 2.5952547e+00,  3.2434185e+00,  7.7471977e-01, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 2.5952547e+00,  4.1019115e+00,  3.2507536e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00]],
#
#        [[ 9.9999997e-06,  3.5240257e+00,  3.8144834e+00, ...,
#           1.0000000e+00,  0.0000000e+00,  1.0000000e+00],
#         [ 9.9999997e-06,  3.9632485e+00,  3.7411430e+00, ...,
#           1.0000000e+00,  0.0000000e+00,  1.0000000e+00],
#         [ 9.9999997e-06,  4.0188570e+00,  3.9687700e+00, ...,
#           1.0000000e+00,  0.0000000e+00,  1.0000000e+00],
#         ...,
#         [ 9.9999997e-06,  4.6761074e+00,  2.9087219e+00, ...,
#           0.0000000e+00,  1.0000000e+00,  0.0000000e+00],
#         [ 9.9999997e-06,  3.2434185e+00,  7.7471977e-01, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 9.9999997e-06,  4.1019115e+00,  3.2507536e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00]]], dtype=float32)

# %%
time_step = X_train.shape[1] # Quantidade de coordenada para equivaler a 1 espaço de tempo
input_dim = X_train.shape[2] #qtd colunas (features)
out = Y_train.shape[2]

# LSTM
start = time.time()
model = Sequential()
model.add(Masking(mask_value=-1.,input_shape=(time_step, input_dim,))) #camada de entrada
model.add(LSTM(32,activation='elu', input_shape=(time_step, input_dim,),return_sequences=True, go_backwards=True
               , kernel_regularizer=l2(0.01), recurrent_regularizer=l2(0.01), bias_regularizer=l2(0.01))) # camada escondida
model.add(Dense(out, activation='sigmoid')) #camada saida

opt = tf.keras.optimizers.Adam(learning_rate=0.01)

model.compile(loss = tf.keras.losses.BinaryCrossentropy(from_logits=False) #https://keras.io/api/losses/probabilistic_losses/ 
              , optimizer= opt #'adam'
              , weighted_metrics=[tf.keras.losses.BinaryCrossentropy(from_logits=False),'accuracy'
              , tf.keras.metrics.Precision()
              , tf.keras.metrics.Recall()]
              , sample_weight_mode="temporal")   #Weights
model.summary()
hist = model.fit(X_train
                 , Y_train
                 , epochs=100
#                  , validation_split=.2
                 ,validation_data=(X_val, Y_val)
                 , verbose=1, batch_size=64
                 , sample_weight=sample_weight_transformado 
                 #(samples, sequence_length)
        )
end = time.time()
print("Total compile time: --------", end - start, 's')
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  masking (Masking)           (None, 2125, 15)          0
#
#  lstm (LSTM)                 (None, 2125, 32)          6144
#
#  dense (Dense)               (None, 2125, 1)           33
#
# =================================================================
# Total params: 6,177
# Trainable params: 6,177
# Non-trainable params: 0
# _________________________________________________________________
# 2023-04-27 00:16:47.763660: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/100
# 12/12 [==============================] - 6s 416ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4760 - precision: 0.3497 - recall: 0.0423 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/100
# 12/12 [==============================] - 5s 382ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/100
# 12/12 [==============================] - 5s 374ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/100
# 12/12 [==============================] - 5s 385ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/100
# 12/12 [==============================] - 5s 394ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/100
# 12/12 [==============================] - 5s 405ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/100
# 12/12 [==============================] - 5s 384ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/100
# 12/12 [==============================] - 5s 399ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/100
# 12/12 [==============================] - 5s 385ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/100
# 12/12 [==============================] - 5s 381ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/100
# 12/12 [==============================] - 5s 402ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/100
# 12/12 [==============================] - 5s 385ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/100
# 12/12 [==============================] - 5s 383ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/100
# 12/12 [==============================] - 5s 384ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/100
# 12/12 [==============================] - 5s 381ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/100
# 12/12 [==============================] - 5s 388ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/100
# 12/12 [==============================] - 5s 391ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/100
# 12/12 [==============================] - 5s 384ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/100
# 12/12 [==============================] - 5s 380ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/100
# 12/12 [==============================] - 5s 389ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 21/100
# 12/12 [==============================] - 5s 380ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 22/100
# 12/12 [==============================] - 4s 373ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 23/100
# 12/12 [==============================] - 5s 394ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 24/100
# 12/12 [==============================] - 5s 399ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 25/100
# 12/12 [==============================] - 5s 388ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 26/100
# 12/12 [==============================] - 5s 390ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 27/100
# 12/12 [==============================] - 5s 379ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 28/100
# 12/12 [==============================] - 5s 402ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 29/100
# 12/12 [==============================] - 5s 396ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 30/100
# 12/12 [==============================] - 5s 394ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 31/100
# 12/12 [==============================] - 5s 387ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 32/100
# 12/12 [==============================] - 5s 398ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 33/100
# 12/12 [==============================] - 5s 400ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 34/100
# 12/12 [==============================] - 5s 402ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 35/100
# 12/12 [==============================] - 4s 376ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 36/100
# 12/12 [==============================] - 5s 393ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 37/100
# 12/12 [==============================] - 5s 405ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 38/100
# 12/12 [==============================] - 5s 399ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 39/100
# 12/12 [==============================] - 5s 402ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 40/100
# 12/12 [==============================] - 5s 403ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 41/100
# 12/12 [==============================] - 5s 394ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 42/100
# 12/12 [==============================] - 5s 389ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 43/100
# 12/12 [==============================] - 5s 398ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 44/100
# 12/12 [==============================] - 5s 403ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 45/100
# 12/12 [==============================] - 5s 396ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 46/100
# 12/12 [==============================] - 5s 386ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 47/100
# 12/12 [==============================] - 5s 383ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 48/100
# 12/12 [==============================] - 5s 380ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 49/100
# 12/12 [==============================] - 5s 395ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 50/100
# 12/12 [==============================] - 5s 397ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 51/100
# 12/12 [==============================] - 4s 375ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 52/100
# 12/12 [==============================] - 5s 400ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 53/100
# 12/12 [==============================] - 5s 376ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 54/100
# 12/12 [==============================] - 5s 380ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 55/100
# 12/12 [==============================] - 5s 408ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 56/100
# 12/12 [==============================] - 5s 378ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 57/100
# 12/12 [==============================] - 5s 395ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 58/100
# 12/12 [==============================] - 5s 384ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 59/100
# 12/12 [==============================] - 5s 397ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 60/100
# 12/12 [==============================] - 5s 404ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 61/100
# 12/12 [==============================] - 5s 390ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 62/100
# 12/12 [==============================] - 5s 382ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 63/100
# 12/12 [==============================] - 5s 391ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 64/100
# 12/12 [==============================] - 5s 406ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 65/100
# 12/12 [==============================] - 5s 397ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 66/100
# 12/12 [==============================] - 5s 388ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 67/100
# 12/12 [==============================] - 5s 388ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 68/100
# 12/12 [==============================] - 5s 390ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 69/100
# 12/12 [==============================] - 5s 408ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 70/100
# 12/12 [==============================] - 5s 395ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 71/100
# 12/12 [==============================] - 5s 396ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 72/100
# 12/12 [==============================] - 5s 397ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 73/100
# 12/12 [==============================] - 5s 387ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 74/100
# 12/12 [==============================] - 5s 417ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 75/100
# 12/12 [==============================] - 5s 392ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 76/100
# 12/12 [==============================] - 5s 386ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 77/100
# 12/12 [==============================] - 5s 388ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 78/100
# 12/12 [==============================] - 5s 401ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 79/100
# 12/12 [==============================] - 5s 393ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 80/100
# 12/12 [==============================] - 4s 377ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 81/100
# 12/12 [==============================] - 5s 386ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 82/100
# 12/12 [==============================] - 5s 379ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 83/100
# 12/12 [==============================] - 5s 391ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 84/100
# 12/12 [==============================] - 5s 381ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 85/100
# 12/12 [==============================] - 5s 378ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 86/100
# 12/12 [==============================] - 5s 401ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 87/100
# 12/12 [==============================] - 5s 400ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 88/100
# 12/12 [==============================] - 5s 408ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 89/100
# 12/12 [==============================] - 5s 380ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 90/100
# 12/12 [==============================] - 5s 383ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 91/100
# 12/12 [==============================] - 5s 385ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 92/100
# 12/12 [==============================] - 5s 382ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 93/100
# 12/12 [==============================] - 5s 389ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 94/100
# 12/12 [==============================] - 5s 378ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 95/100
# 12/12 [==============================] - 5s 388ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 96/100
# 12/12 [==============================] - 5s 385ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 97/100
# 12/12 [==============================] - 5s 377ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 98/100
# 12/12 [==============================] - 5s 388ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 99/100
# 12/12 [==============================] - 5s 382ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 100/100
# 12/12 [==============================] - 5s 395ms/step - loss: nan - binary_crossentropy: nan - accuracy: 0.4944 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: nan - val_binary_crossentropy: nan - val_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Total compile time: -------- 468.4808418750763 s

# %%
# summarize history for loss
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# summarize history for binary crossentropy
plt.plot(hist.history['binary_crossentropy'])
plt.plot(hist.history['val_binary_crossentropy'])
plt.title('model binary crossentropy')
plt.ylabel('binary crossentropy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()


# summarize history for accuracy
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# summarize history for precision
plt.plot(hist.history['precision'])
plt.plot(hist.history['val_precision'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# summarize history for recall
plt.plot(hist.history['recall'])
plt.plot(hist.history['val_recall'])
plt.title('model recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  masking (Masking)           (None, 2125, 15)          0
#
#  lstm (LSTM)                 (None, 2125, 32)          6144
#
#  dense (Dense)               (None, 2125, 1)           33
#
# =================================================================
# Total params: 6,177
# Trainable params: 6,177
# Non-trainable params: 0
# _________________________________________________________________

# %%
predictions = (model.predict(X_teste, verbose=1) > 0.5).astype("int32").reshape((1,-1))
# Out:
# 5/5 [==============================] - 0s 63ms/step

# %%
def flatten(l):
    return [item for sublist in l for item in sublist]

# %%
pred_y = pd.DataFrame(flatten(predictions), columns=['Prediction'])

# %%
matriz_confusao(teste[['ocorrencia']],pred_y,'3')
# Out:
# +-----------------------+
# |           3           |
# +-----------+-----------+
# | Métrica   | Resultado |
# +-----------+-----------+
# | Acurácia: |       1.0 |
# | Precisão: |       0.0 |
# | Recall:   |       0.0 |
# | F1-Score: |       0.0 |
# +-----------+-----------+
# /home/pdpa-chuvas/Deslizamento/env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
bla = model.predict(X_teste, verbose=1)
# Out:
# 5/5 [==============================] - 0s 61ms/step

# %%
bla.shape
# Out:
# (144, 2125, 1)
